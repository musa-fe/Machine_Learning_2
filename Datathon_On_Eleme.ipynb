# %% [markdown]
# <a href="https://colab.research.google.com/github/musa-fe/Machine_Learning_2/blob/main/Datathon_On_Eleme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/gdrive/MyDrive/balanced_smart_manufacturing_data.csv")

# %%
df.head()
# Out:
#              timestamp  machine_id  temperature  vibration  humidity  \
# 0  2025-01-14 12:41:00          20        60.98      52.56     76.67
# 1  2025-03-10 09:58:00          17        62.79      79.95     33.81
# 2  2025-02-20 11:52:00          38        66.29      51.97     77.06
# 3  2025-02-20 20:46:00          16        69.05      44.57     71.64
# 4  2025-01-19 03:22:00          12        88.11      68.61     40.16
#
#    pressure  energy_consumption  machine_status  anomaly_flag  \
# 0      4.72                1.67               1             0
# 1      4.16                3.41               1             0
# 2      4.49                4.06               1             0
# 3      2.68                2.17               1             0
# 4      4.78                0.53               1             0
#
#    predicted_remaining_life failure_type  downtime_risk  maintenance_required
# 0                       241       Normal            0.0                     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   timestamp                 1030 non-null   object
#  1   machine_id                1030 non-null   int64
#  2   temperature               1030 non-null   float64
#  3   vibration                 1030 non-null   float64
#  4   humidity                  1030 non-null   float64
#  5   pressure                  1030 non-null   float64
#  6   energy_consumption        1030 non-null   float64
#  7   machine_status            1030 non-null   int64
#  8   anomaly_flag              1030 non-null   int64
#  9   predicted_remaining_life  1030 non-null   int64
#  10  failure_type              1030 non-null   object
#  11  downtime_risk             1030 non-null   float64
#  12  maintenance_required      1030 non-null   int64
# dtypes: float64(6), int64(5), object(2)
# ...
